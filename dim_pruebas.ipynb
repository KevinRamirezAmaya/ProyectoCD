# %%
import pandas as pd
import numpy as np
import psycopg2
import sqlalchemy as db
from sqlalchemy import create_engine
import yaml

# %%
with open('C:\\Users\\dylan\\OneDrive\\Documentos\\mensajeria\\config.yml', 'r') as f:
    config = yaml.safe_load(f)
    config_co = config['mensajeria']
    config_etl = config['ETL_PRO']

# Construct the database URL
url_co = (f"{config_co['drivername']}://{config_co['user']}:{config_co['password']}@{config_co['host']}:"
          f"{config_co['port']}/{config_co['dbname']}")
url_etl = (f"{config_etl['drivername']}://{config_etl['user']}:{config_etl['password']}@{config_etl['host']}:"
           f"{config_etl['port']}/{config_etl['dbname']}")
# Create the SQLAlchemy Engine
mensajeria = create_engine(url_co)
etl_conn = create_engine(url_etl)

# %%
dim_persona = pd.read_sql_table('clientes_datosmensajero', mensajeria)
dim_persona.head(10)
# Out:
#    datos_id
# 0         1
# 1         2
# 2         3

# %%
df = pd.read_sql_table('mensajeria_estado', mensajeria)
df.head
# Out:
# <bound method NDFrame.head of    id                  nombre             descripcion
# 0   4  Recogido por mensajero  Recogido por mensajero
# 1   5    Entregado en destino    Entregado en destino
# 2   3             Con novedad           Tiene novedad
# 3   6      Terminado completo      Terminado completo
# 4   1                Iniciado   Creado por el usuario
# 5   2  Con mensajero Asignado  Con mensajero Asignado>

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)
df = pd.read_sql_table('mensajeria_novedadesservicio', mensajeria)
df.head(100).T
# Out:
#                                         0                          1   \
# id                                       4                          5
# fecha_novedad    2023-11-30 05:00:00+00:00  2023-11-30 05:00:00+00:00
# tipo_novedad_id                          1                          1
# descripcion                              A                       Halo
# servicio_id                             51                         51
# es_prueba                             True                       True
# mensajero_id                             7                          7
#
#                                         2                          3   \
# id                                       6                          7
# fecha_novedad    2023-11-30 05:00:00+00:00  2023-11-30 05:00:00+00:00
# tipo_novedad_id                          1                          1
# descripcion                              A                          B
# servicio_id                             51                         51
# es_prueba                             True                       True
# mensajero_id                             7                          7
#
#                                         4                          5   \
# id                                       8                          9
# fecha_novedad    2023-11-30 05:00:00+00:00  2023-11-30 05:00:00+00:00
# tipo_novedad_id                          1                          2
# descripcion                              A                          V
# servicio_id                             51                         51
# es_prueba                             True                       True
# mensajero_id                             7                          7
#
#                                         6                          7   \
# id                                      10                         11
# fecha_novedad    2023-11-30 05:00:00+00:00  2023-11-30 05:00:00+00:00
# tipo_novedad_id                          2                          2
# descripcion                              V                          C
# servicio_id                             51                         51
# es_prueba                             True                       True
# mensajero_id                             7                          7
#
#                                         8                          9   \
# id                                      12                         15
# fecha_novedad    2023-11-30 05:00:00+00:00  2023-12-07 05:00:00+00:00
# tipo_novedad_id                          1                          2
# descripcion                              B                  Me pinché
# servicio_id                             29                         29
# es_prueba                             True                       True
# mensajero_id                             7                          7
#
#                                         10                         11  \
# id                                      16                         17
# fecha_novedad    2023-12-07 05:00:00+00:00  2023-12-07 05:00:00+00:00
# tipo_novedad_id                          1                          1
# descripcion             Esperando muestras            Muestras listas
# servicio_id                             57                         57
# es_prueba                             True                       True
# mensajero_id                             7                          7
#
#                                         12                                13  \
# id                                      18                                19
# fecha_novedad    2023-12-09 05:00:00+00:00  2023-12-28 16:00:14.053979+00:00
# tipo_novedad_id                          2                                 2
# descripcion                No puedo seguir                                 X
# servicio_id                             57                                68
# es_prueba                             True                             False
# mensajero_id                             7                                 7
#
#                                                14  \
# id                                             20
# fecha_novedad    2023-12-28 16:01:17.471902+00:00
# tipo_novedad_id                                 1
# descripcion                                     X
# servicio_id                                    68
# es_prueba                                   False
# mensajero_id                                    7
#
#                                                15  \
# id                                             21
# fecha_novedad    2023-12-28 16:01:38.521117+00:00
# tipo_novedad_id                                 2
# descripcion
# servicio_id                                    68
# es_prueba                                   False
# mensajero_id                                    7
#
#                                                16                         17  \
# id                                             22                         23
# fecha_novedad    2023-12-28 19:02:01.193737+00:00  2024-01-03 05:00:00+00:00
# tipo_novedad_id                                 2                          2
# descripcion                    no puedo continuar            No puedo seguir
# servicio_id                                    73                         81
# es_prueba                                   False                       True
# mensajero_id                                    7                          7
#
#                                         18                                19  \
# id                                      24                                25
# fecha_novedad    2024-01-03 05:00:00+00:00  2024-01-04 00:15:49.827327+00:00
# tipo_novedad_id                          1                                 1
# descripcion            Me acabe de pinchar                            DEMORA
# servicio_id                             80                                85
# es_prueba                             True                             False
# mensajero_id                             7                                 7
#
#                                         20                         21  \
# id                                      26                         27
# fecha_novedad    2024-01-04 05:00:00+00:00  2024-01-03 05:00:00+00:00
# tipo_novedad_id                          1                          1
# descripcion      Hay trancon en la calle 5                          V
# servicio_id                             84                         88
# es_prueba                             True                       True
# mensajero_id                             7                          7
#
#                                                     22  \
# id                                                  28
# fecha_novedad                2024-01-04 05:00:00+00:00
# tipo_novedad_id                                      2
# descripcion      Se me apagó la moto no quiere prender
# servicio_id                                         90
# es_prueba                                         True
# mensajero_id                                         7
#
#                                         23  \
# id                                      29
# fecha_novedad    2024-01-11 05:00:00+00:00
# tipo_novedad_id                          1
# descripcion                      Me pinche
# servicio_id                             94
# es_prueba                             True
# mensajero_id                            29
#
#                                                    24  \
# id                                                 30
# fecha_novedad               2024-01-11 05:00:00+00:00
# tipo_novedad_id                                     2
# descripcion      Me vare estoy en la carrera 1 con 34
# servicio_id                                        94
# es_prueba                                        True
# mensajero_id                                       29
#
#                                                25  \
# id                                             31
# fecha_novedad    2024-01-11 19:36:21.010444+00:00
# tipo_novedad_id                                 1
# descripcion        Esperando pedido en el almacen
# servicio_id                                    83
# es_prueba                                   False
# mensajero_id                                    7
#
#                                                26  \
# id                                             32
# fecha_novedad    2024-01-11 19:37:29.033626+00:00
# tipo_novedad_id                                 1
# descripcion            Novedad desde la app movil
# servicio_id                                    83
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                27  \
# id                                             33
# fecha_novedad    2024-01-19 00:53:14.973138+00:00
# tipo_novedad_id                                 2
# descripcion                             Me pinche
# servicio_id                                    99
# es_prueba                                    True
# mensajero_id                                   29
#
#                                                28  \
# id                                             34
# fecha_novedad    2024-01-23 21:39:31.823434+00:00
# tipo_novedad_id                                 2
# descripcion           La moto no quiere funcionar
# servicio_id                                   129
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                29  \
# id                                             35
# fecha_novedad    2024-01-24 17:31:11.033341+00:00
# tipo_novedad_id                                 1
# descripcion              Me demoro estoy oinchado
# servicio_id                                   144
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                30  \
# id                                             36
# fecha_novedad    2024-01-24 20:02:40.482832+00:00
# tipo_novedad_id                                 1
# descripcion                             Me pinche
# servicio_id                                   140
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                          31  \
# id                                                       37
# fecha_novedad              2024-01-24 20:03:07.583583+00:00
# tipo_novedad_id                                           2
# descripcion      Me vare estoy por las cancha panamericanas
# servicio_id                                             140
# es_prueba                                              True
# mensajero_id                                              3
#
#                                                32  \
# id                                             38
# fecha_novedad    2024-01-25 16:25:01.429005+00:00
# tipo_novedad_id                                 2
# descripcion                       Lo toma yulieth
# servicio_id                                   157
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                33  \
# id                                             39
# fecha_novedad    2024-01-25 16:58:35.888847+00:00
# tipo_novedad_id                                 1
# descripcion           En taller alianza no lo hay
# servicio_id                                   160
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                      34  \
# id                                                   40
# fecha_novedad          2024-01-25 18:30:48.652746+00:00
# tipo_novedad_id                                       1
# descripcion      Arrima a dfm y no hay repuesto similar
# servicio_id                                         161
# es_prueba                                          True
# mensajero_id                                          3
#
#                                                 35  \
# id                                              41
# fecha_novedad     2024-01-25 18:31:50.652155+00:00
# tipo_novedad_id                                  2
# descripcion      Me vare la moto no quiere prender
# servicio_id                                    161
# es_prueba                                     True
# mensajero_id                                     3
#
#                                                        36  \
# id                                                     42
# fecha_novedad            2024-01-25 18:44:13.266945+00:00
# tipo_novedad_id                                         2
# descripcion      Me vare me encuentro en carrera 23 10 56
# servicio_id                                           161
# es_prueba                                            True
# mensajero_id                                            3
#
#                                                37  \
# id                                             43
# fecha_novedad    2024-01-25 19:52:39.193810+00:00
# tipo_novedad_id                                 1
# descripcion        Arrime a dfm no hay mx similar
# servicio_id                                   165
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                                38  \
# id                                                             44
# fecha_novedad                    2024-01-25 20:19:51.980763+00:00
# tipo_novedad_id                                                 1
# descripcion      Demora en la recta cali Palmira me paro trabsito
# servicio_id                                                   168
# es_prueba                                                    True
# mensajero_id                                                    3
#
#                                                     39  \
# id                                                  45
# fecha_novedad         2024-01-25 20:34:12.633982+00:00
# tipo_novedad_id                                      1
# descripcion      Arrime a celeste no ha repuesto igual
# servicio_id                                        157
# es_prueba                                         True
# mensajero_id                                         3
#
#                                                40  \
# id                                             46
# fecha_novedad    2024-01-25 20:45:12.311557+00:00
# tipo_novedad_id                                 1
# descripcion                                No hoy
# servicio_id                                   170
# es_prueba                                    True
# mensajero_id                                    8
#
#                                                        41  \
# id                                                     47
# fecha_novedad            2024-01-26 14:47:12.522890+00:00
# tipo_novedad_id                                         1
# descripcion      Esperando a que reciban los medicamentos
# servicio_id                                           178
# es_prueba                                            True
# mensajero_id                                            3
#
#                                                        42  \
# id                                                     48
# fecha_novedad            2024-01-26 14:47:13.338647+00:00
# tipo_novedad_id                                         1
# descripcion      Esperando a que reciban los medicamentos
# servicio_id                                           178
# es_prueba                                            True
# mensajero_id                                            3
#
#                                                                 43  \
# id                                                              49
# fecha_novedad                     2024-01-26 16:26:40.052097+00:00
# tipo_novedad_id                                                  1
# descripcion      Buscando en el huv los funcionarios para recla...
# servicio_id                                                    177
# es_prueba                                                     True
# mensajero_id                                                     3
#
#                                                44  \
# id                                             50
# fecha_novedad    2024-01-26 22:58:07.989245+00:00
# tipo_novedad_id                                 1
# descripcion                               Novedad
# servicio_id                                   187
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                45  \
# id                                             51
# fecha_novedad    2024-01-26 23:05:15.558305+00:00
# tipo_novedad_id                                 1
# descripcion            novedad antes de finalizar
# servicio_id                                   187
# es_prueba                                   False
# mensajero_id                                    7
#
#                                                  46  \
# id                                               52
# fecha_novedad      2024-01-26 23:06:46.722259+00:00
# tipo_novedad_id                                   1
# descripcion      segunda novedad antes del terminar
# servicio_id                                     187
# es_prueba                                     False
# mensajero_id                                      7
#
#                                                                 47  \
# id                                                              53
# fecha_novedad                     2024-01-27 18:12:14.491548+00:00
# tipo_novedad_id                                                  1
# descripcion      El cliente acepta dejar el repuesto\nY firma f...
# servicio_id                                                    203
# es_prueba                                                     True
# mensajero_id                                                     8
#
#                                                                 48  \
# id                                                              54
# fecha_novedad                     2024-01-27 18:12:16.674711+00:00
# tipo_novedad_id                                                  1
# descripcion      El cliente acepta dejar el repuesto\nY firma f...
# servicio_id                                                    203
# es_prueba                                                     True
# mensajero_id                                                     8
#
#                                                                 49  \
# id                                                              55
# fecha_novedad                     2024-01-27 18:20:19.983153+00:00
# tipo_novedad_id                                                  2
# descripcion      Se cancela el servicio cliente no contesta se ...
# servicio_id                                                    206
# es_prueba                                                     True
# mensajero_id                                                    19
#
#                                                                 50  \
# id                                                              56
# fecha_novedad                     2024-01-29 00:02:21.211620+00:00
# tipo_novedad_id                                                  1
# descripcion      Estoy en trauma pero estoy esperando otras mx ...
# servicio_id                                                    219
# es_prueba                                                     True
# mensajero_id                                                     3
#
#                                                                 51  \
# id                                                              57
# fecha_novedad                     2024-01-29 16:24:10.804182+00:00
# tipo_novedad_id                                                  1
# descripcion      En espera a que llegue el encargado de entrega...
# servicio_id                                                    231
# es_prueba                                                     True
# mensajero_id                                                    27
#
#                                                                 52  \
# id                                                              58
# fecha_novedad                     2024-01-29 18:40:24.943103+00:00
# tipo_novedad_id                                                  2
# descripcion      Secretaria estaba cerrado se deja mx en torres...
# servicio_id                                                    249
# es_prueba                                                     True
# mensajero_id                                                    17
#
#                                                53  \
# id                                             59
# fecha_novedad    2024-01-29 18:54:00.266067+00:00
# tipo_novedad_id                                 2
# descripcion                                    Ok
# servicio_id                                   258
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                54  \
# id                                             60
# fecha_novedad    2024-01-30 15:21:26.954263+00:00
# tipo_novedad_id                                 1
# descripcion                   Termino el servicio
# servicio_id                                   287
# es_prueba                                    True
# mensajero_id                                   17
#
#                                                55  \
# id                                             61
# fecha_novedad    2024-01-30 15:44:29.334285+00:00
# tipo_novedad_id                                 2
# descripcion                    Por cambio de ruta
# servicio_id                                   288
# es_prueba                                    True
# mensajero_id                                   17
#
#                                                56  \
# id                                             62
# fecha_novedad    2024-01-30 23:45:12.065779+00:00
# tipo_novedad_id                                 1
# descripcion                                Demora
# servicio_id                                    79
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                      57  \
# id                                                   63
# fecha_novedad          2024-01-31 14:27:03.029728+00:00
# tipo_novedad_id                                       1
# descripcion      Por fallas ni puede cargar el servicio
# servicio_id                                         289
# es_prueba                                          True
# mensajero_id                                         17
#
#                                                                 58  \
# id                                                              64
# fecha_novedad                     2024-01-31 14:34:28.301561+00:00
# tipo_novedad_id                                                  1
# descripcion      Por una falla no se pudo montar el servicio te...
# servicio_id                                                    289
# es_prueba                                                     True
# mensajero_id                                                    17
#
#                                                59  \
# id                                             65
# fecha_novedad    2024-01-31 14:34:47.105681+00:00
# tipo_novedad_id                                 2
# descripcion                    Se cayó el sistema
# servicio_id                                   289
# es_prueba                                    True
# mensajero_id                                   17
#
#                                                 60  \
# id                                              66
# fecha_novedad     2024-01-31 15:58:02.464946+00:00
# tipo_novedad_id                                  1
# descripcion      Esperando respuesta del proveedor
# servicio_id                                    339
# es_prueba                                     True
# mensajero_id                                     8
#
#                                                                 61  \
# id                                                              67
# fecha_novedad                     2024-01-31 18:44:03.874633+00:00
# tipo_novedad_id                                                  1
# descripcion      En bodega 3 solo recojo un repuesto el otro in...
# servicio_id                                                    351
# es_prueba                                                     True
# mensajero_id                                                    24
#
#                                                                 62  \
# id                                                              68
# fecha_novedad                     2024-01-31 19:46:04.391666+00:00
# tipo_novedad_id                                                  2
# descripcion      En automarcali no se recoje repuesto de de la ...
# servicio_id                                                    356
# es_prueba                                                     True
# mensajero_id                                                    34
#
#                                                63  \
# id                                             69
# fecha_novedad    2024-01-31 22:11:00.378470+00:00
# tipo_novedad_id                                 2
# descripcion              No puedo continuar 31 01
# servicio_id                                    81
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                          64  \
# id                                                       70
# fecha_novedad              2024-01-31 23:06:26.171137+00:00
# tipo_novedad_id                                           1
# descripcion      No se despacha x q bodega no entrega copia
# servicio_id                                             372
# es_prueba                                              True
# mensajero_id                                             25
#
#                                                65  \
# id                                             71
# fecha_novedad    2024-02-01 04:55:00.434629+00:00
# tipo_novedad_id                                 2
# descripcion                                  Oops
# servicio_id                                   377
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                                 66  \
# id                                                              72
# fecha_novedad                     2024-02-01 13:47:56.406232+00:00
# tipo_novedad_id                                                  1
# descripcion      Proveedor, el arranque, no lo hay\nLo voy   a ...
# servicio_id                                                    382
# es_prueba                                                     True
# mensajero_id                                                     8
#
#                                                                 67  \
# id                                                              73
# fecha_novedad                     2024-02-01 14:32:48.482782+00:00
# tipo_novedad_id                                                  1
# descripcion      El terminal que traje de muestra, si aplica,  ...
# servicio_id                                                    382
# es_prueba                                                     True
# mensajero_id                                                     8
#
#                                                                 68  \
# id                                                              74
# fecha_novedad                     2024-02-01 14:32:49.755059+00:00
# tipo_novedad_id                                                  1
# descripcion      El terminal que traje de muestra, si aplica,  ...
# servicio_id                                                    382
# es_prueba                                                     True
# mensajero_id                                                     8
#
#                                                           69  \
# id                                                        75
# fecha_novedad               2024-02-01 17:06:25.415723+00:00
# tipo_novedad_id                                            1
# descripcion      Cerrado en alianza se entrega cuando habran
# servicio_id                                              399
# es_prueba                                               True
# mensajero_id                                              25
#
#                                                70  \
# id                                             76
# fecha_novedad    2024-02-02 15:25:23.074038+00:00
# tipo_novedad_id                                 1
# descripcion        Igual le informe a Juan al cel
# servicio_id                                   445
# es_prueba                                    True
# mensajero_id                                    8
#
#                                                                 71  \
# id                                                              77
# fecha_novedad                     2024-02-02 16:29:59.602667+00:00
# tipo_novedad_id                                                  1
# descripcion      Buenos días actualmente está suspendido el ser...
# servicio_id                                                    454
# es_prueba                                                     True
# mensajero_id                                                     3
#
#                                                                 72  \
# id                                                              78
# fecha_novedad                     2024-02-03 14:33:14.871331+00:00
# tipo_novedad_id                                                  1
# descripcion      Buenos días señoras y señores, estoy donde el ...
# servicio_id                                                    505
# es_prueba                                                     True
# mensajero_id                                                     8
#
#                                                        73  \
# id                                                     79
# fecha_novedad            2024-02-03 15:14:23.320421+00:00
# tipo_novedad_id                                         1
# descripcion      Buenos días, el servicio está suspendido
# servicio_id                                           514
# es_prueba                                            True
# mensajero_id                                            3
#
#                                                                 74  \
# id                                                              80
# fecha_novedad                     2024-02-03 15:32:40.716766+00:00
# tipo_novedad_id                                                  1
# descripcion      Me encuentro en Redox y me informa Sebastián q...
# servicio_id                                                    516
# es_prueba                                                     True
# mensajero_id                                                    38
#
#                                                75  \
# id                                             81
# fecha_novedad    2024-02-03 15:41:13.893405+00:00
# tipo_novedad_id                                 1
# descripcion                      Cerrado el local
# servicio_id                                   516
# es_prueba                                    True
# mensajero_id                                   38
#
#                                                76  \
# id                                             82
# fecha_novedad    2024-02-04 16:15:40.758223+00:00
# tipo_novedad_id                                 2
# descripcion                                  Vxvx
# servicio_id                                   377
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                77  \
# id                                             83
# fecha_novedad    2024-02-04 17:47:10.153102+00:00
# tipo_novedad_id                                 2
# descripcion                                     V
# servicio_id                                   187
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                78  \
# id                                             84
# fecha_novedad    2024-02-04 20:29:16.027285+00:00
# tipo_novedad_id                                 2
# descripcion                             Me pinche
# servicio_id                                   540
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                79  \
# id                                             85
# fecha_novedad    2024-02-04 21:03:31.192009+00:00
# tipo_novedad_id                                 2
# descripcion                                    Xb
# servicio_id                                   540
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                80  \
# id                                             86
# fecha_novedad    2024-02-04 21:05:54.816598+00:00
# tipo_novedad_id                                 2
# descripcion           No puedo porquecmecacidenre
# servicio_id                                   515
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                81  \
# id                                             87
# fecha_novedad    2024-02-04 21:25:33.637278+00:00
# tipo_novedad_id                                 2
# descripcion                               Me vare
# servicio_id                                   541
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                82  \
# id                                             88
# fecha_novedad    2024-02-04 21:34:08.886274+00:00
# tipo_novedad_id                                 2
# descripcion                                 Se to
# servicio_id                                   541
# es_prueba                                    True
# mensajero_id                                   18
#
#                                                                 83  \
# id                                                              89
# fecha_novedad                     2024-02-05 16:43:07.718800+00:00
# tipo_novedad_id                                                  1
# descripcion      Autorizada compra, de acuerdo a la consulta, e...
# servicio_id                                                    558
# es_prueba                                                     True
# mensajero_id                                                     8
#
#                                                84  \
# id                                             90
# fecha_novedad    2024-02-05 21:28:02.859403+00:00
# tipo_novedad_id                                 2
# descripcion                                   Vvv
# servicio_id                                   589
# es_prueba                                    True
# mensajero_id                                    7
#
#                                                                 85  \
# id                                                              91
# fecha_novedad                     2024-02-05 21:28:28.777277+00:00
# tipo_novedad_id                                                  2
# descripcion      Me informas que no se está mandando nada por c...
# servicio_id                                                    585
# es_prueba                                                     True
# mensajero_id                                                    37
#
#                                                86  \
# id                                             92
# fecha_novedad    2024-02-05 21:30:45.368638+00:00
# tipo_novedad_id                                 1
# descripcion           Adicional con unos glóbulos
# servicio_id                                   578
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                                 87  \
# id                                                              93
# fecha_novedad                     2024-02-06 01:41:50.512302+00:00
# tipo_novedad_id                                                  1
# descripcion      Se toma y se deja anotacion en la app pero no ...
# servicio_id                                                    579
# es_prueba                                                     True
# mensajero_id                                                    25
#
#                                                                 88  \
# id                                                              94
# fecha_novedad                     2024-02-06 01:41:52.534713+00:00
# tipo_novedad_id                                                  1
# descripcion      Se toma y se deja anotacion en la app pero no ...
# servicio_id                                                    579
# es_prueba                                                     True
# mensajero_id                                                    25
#
#                                                89  \
# id                                             95
# fecha_novedad    2024-02-06 12:46:28.911109+00:00
# tipo_novedad_id                                 1
# descripcion               Willian roa CC 91528823
# servicio_id                                   600
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                90  \
# id                                             96
# fecha_novedad    2024-02-06 16:05:43.291457+00:00
# tipo_novedad_id                                 1
# descripcion                    No aparecen las mx
# servicio_id                                   617
# es_prueba                                    True
# mensajero_id                                    3
#
#                                                                 91  \
# id                                                              97
# fecha_novedad                     2024-02-06 16:51:44.185130+00:00
# tipo_novedad_id                                                  1
# descripcion      Se recoge la consignación 2pm, enterado Freddy...
# servicio_id                                                    622
# es_prueba                                                     True
# mensajero_id                                                     8
#
#                                                                 92  \
# id                                                              98
# fecha_novedad                     2024-02-06 20:59:33.001682+00:00
# tipo_novedad_id                                                  1
# descripcion      Se envía devolución de mercado libre con el co...
# servicio_id                                                    636
# es_prueba                                                     True
# mensajero_id                                                    22
#
#                                                                 93  \
# id                                                              99
# fecha_novedad                     2024-02-06 22:30:56.084908+00:00
# tipo_novedad_id                                                  1
# descripcion      El cliente hace el pago por transferencia por ...
# servicio_id                                                    637
# es_prueba                                                     True
# mensajero_id                                                    22
#
#                                                                 94  \
# id                                                             100
# fecha_novedad                     2024-02-06 22:30:56.923847+00:00
# tipo_novedad_id                                                  1
# descripcion      El cliente hace el pago por transferencia por ...
# servicio_id                                                    637
# es_prueba                                                     True
# mensajero_id                                                    22
#
#                                                                 95  \
# id                                                             101
# fecha_novedad                     2024-02-07 15:20:18.589179+00:00
# tipo_novedad_id                                                  1
# descripcion      Se entrega factura frep 54172 para que sea leg...
# servicio_id                                                    637
# es_prueba                                                     True
# mensajero_id                                                    22
#
#                                                96  \
# id                                            102
# fecha_novedad    2024-02-07 20:03:36.193325+00:00
# tipo_novedad_id                                 2
# descripcion             Recojido por Cristian roa
# servicio_id                                   711
# es_prueba                                    True
# mensajero_id                                   16
#
#                                                                 97  \
# id                                                             103
# fecha_novedad                     2024-02-07 20:46:19.966357+00:00
# tipo_novedad_id                                                  1
# descripcion      Por favor arrimar la mx al laboratorio están h...
# servicio_id                                                    739
# es_prueba                                                     True
# mensajero_id                                                     3
#
#                                                98  \
# id                                            104
# fecha_novedad    2024-02-07 22:40:53.297263+00:00
# tipo_novedad_id                                 1
# descripcion                    Servicio duplicado
# servicio_id                                   732
# es_prueba                                    True
# mensajero_id                                   16
#
#                                                99
# id                                            105
# fecha_novedad    2024-02-08 01:58:53.617062+00:00
# tipo_novedad_id                                 2
# descripcion                               Novedad
# servicio_id                                   759
# es_prueba                                    True
# mensajero_id                                    7

# %%
tabla_estados = pd.read_sql_table('mensajeria_estadosservicio', mensajeria)
tabla_estados.head(100)
# Out:
#        id      fecha      hora  foto           observaciones  estado_id  \
# 0    1014 2024-01-29  01:13:32  foto                 4 tubos          4
# 1    1484 2024-01-30  18:45:12  foto                  Demora          3
# 2    2829 2024-02-06  11:34:04  foto          Compra exitosa          5
# 3    1888 2024-02-01  14:50:39  foto                   Zzxzz          4
# 4   32312 2024-04-06  16:11:21  foto                      No          3
# ..    ...        ...       ...   ...                     ...        ...
# 95  40593 2024-04-19  11:39:04  foto          Recibido David          5
# 96  40698 2024-04-19  13:04:25  foto             Recibe gina          5
# 97  41380 2024-04-20  13:56:47  foto           Recibe Andrés          5
# 98  41717 2024-04-22  10:17:32  foto           Recibe francy          6
# 99  42264 2024-04-22  17:06:28  foto  Con mensajero Asignado          2
#
#     servicio_id  es_prueba foto_binary
# 0           226      False        None
# 1            79       True        None
# 2           613      False        None
# 3           376      False        None
# 4          7164       True        None
# ..          ...        ...         ...
# 95         8866      False        None
# 96         9052      False        None
# 97         9158      False        None
# 98         9283      False        None
# 99         9419       True        None
#
# [100 rows x 9 columns]

# %%
tabla_estados['estado_id'].value_counts()
# Out:
# estado_id
# 2    30249
# 1    29627
# 4    27542
# 5    27335
# 6     8447
# 3     5202
# Name: count, dtype: int64

# %%
columnas_hora = [
    'hora_iniciado',
    'hora_mensajero_asignado',
    'hora_recogido_mensajero',
    'hora_entregado',
    'hora_finalizado_completo'
]

for col in columnas_hora:
    if col in trans_servicio.columns:
        trans_servicio[col] = trans_servicio[col].apply(
            lambda t: t.strftime('%H:%M:%S') if pd.notna(t) else t
        )
